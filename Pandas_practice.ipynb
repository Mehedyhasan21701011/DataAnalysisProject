# %%
import pandas as pd
cars = {
    'name':['Toyota','Honda','BMW','TVS'],
    'price':[23000,24000,25000,26000]
}

df = pd.DataFrame(cars)
df
# Out:
#      name  price
# 0  Toyota  23000
# 1   Honda  24000
# 2     BMW  25000
# 3     TVS  26000

# %%
li = ['Toyota','Honda','BMW','TVS']
df = pd.DataFrame(li)
df
# Out:
#         0
# 0  Toyota
# 1   Honda
# 2     BMW
# 3     TVS

# %%
name = ['Toyota','Honda','BMW','TVS']
price = [23000,24000,25000,26000]
df = pd.DataFrame(list(zip(name,price)))
df
# Out:
#         0      1
# 0  Toyota  23000
# 1   Honda  24000
# 2     BMW  25000
# 3     TVS  26000

# %%
name = ['Toyota','Honda','BMW','TVS']
price = [23000,24000,25000,26000]
df = pd.DataFrame(list(zip(name,price)),columns=['name','price'])
df
# Out:
#      name  price
# 0  Toyota  23000
# 1   Honda  24000
# 2     BMW  25000
# 3     TVS  26000

# %%
# Createt a sub DataFrame
# df = pd.read_csv('file_name.csv',names = ['col1_name','col2_name','col3_name'])
# df

# %%
# Skip a specific row
# df = pd.read_csv('file_name.csv',skiprows=[1,2])
# df

# %%
# Making unexcepted value as  null value
# df = pd.read_csv('file_name.csv',na_values = ['No','Not Available','ect'])

# %%
df.to_csv('new_csv.csv')

# %%
file = pd.read_csv('new_csv.csv',na_values = ['No','Not Available','ect'])
file
# Out:
#    Unnamed: 0    name  price
# 0           0  Toyota  23000
# 1           1   Honda  24000
# 2           2     BMW  25000
# 3           3     TVS  26000

# %%
file.name
# Out:
# 0    Toyota
# 1     Honda
# 2       BMW
# 3       TVS
# Name: name, dtype: object

# %%
# We can pass a function to read excle file
# def function(x):
#   if x == 'M':
#     return 'Male'
#   elif x == 'F':
#     return 'Female'
#   else:
#     return 'NaN'

# file = pd.read_excel('file_name.excel',converters={'Gender':function})
# file

# %%
# We can read multiple sheet from same excle file
# sheet_1 = pd.read_excel('file_name.excel',sheet_name = 'data')
# sheet_2 = pd.read_excel('file_name.excel',sheet_name = 'new_data')

# %%
# create multiple sheet in same excel file

# with pd.ExcelWriter('new_excel.xlsx') as writer:
#   data.to_excel(writer,sheet_name = 'Sheet-1')
#   new_data.to_excel(writer,sheet_name = 'Sheet-2')

# %%
# Reading and writing text file
# file = pd.read_csv('text_file.txt',delimiter = '\t')
# file

# %%
# fill null value with 0
# file.fillna(0)
# file.name.fillna('No Name')
# file.fillna({'name':'No Name','price':0})
# file.fillna(method='ffill')
# file.fillna(method='bfill')
# file.fillna(method='bfill',axis = 'columns')
# file.fillna(method='bfill',limit = 1)
# file.fillna(file.mean())

# %%
import pandas as pd

file = pd.read_csv('/content/file (1).csv')
file.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
# Interpolate missing value
file = file.interpolate()
# Time interpolate
file = file.interpolate(method = 'time')

# %%
import numpy as np

# %%
df = pd.DataFrame({'A':[1,'nan',3,4],'B':[5,'nan',7,8],'C':[9,10,11,'nan']})
df
# Out:
#      A    B    C
# 0    1    5    9
# 1  nan  nan   10
# 2    3    7   11
# 3    4    8  nan

# %%
df.to_csv('new_csv.csv')

# %%
file = pd.read_csv('new_csv.csv',na_values = ['nan'])
file
# Out:
#    Unnamed: 0    A    B     C
# 0           0  1.0  5.0   9.0
# 1           1  NaN  NaN  10.0
# 2           2  3.0  7.0  11.0
# 3           3  4.0  8.0   NaN

# %%
file.interpolate()
# Out:
#    Unnamed: 0    A    B     C
# 0           0  1.0  5.0   9.0
# 1           1  2.0  6.0  10.0
# 2           2  3.0  7.0  11.0
# 3           3  4.0  8.0  11.0

# %%
file.interpolate(limit = 1)
file.interpolate(limit = 1,limit_direction = 'forward')
file.interpolate(limit = 1,limit_direction = 'backward')

# %%
# Drop missing value
file.dropna()
# with threshold amount of null value
file.dropna(thresh=2)

# %%
# Group by
import numpy as np
import pandas as pd

file = pd.read_csv('/content/file (1).csv')
file
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
Group = file.groupby('Weather')

# %%
Group.first()

# %%
Gorup.last()

# %%
Group.get_group('Fog')
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# 5        1/1/2012 5:00    -1.4              -3.3         87                9
# 6        1/1/2012 6:00    -1.5              -3.1         89                7
# ...                ...     ...               ...        ...              ...
# 8716   12/29/2012 4:00   -16.0             -17.2         90                6
# 8717   12/29/2012 5:00   -14.8             -15.9         91                4
# 8718   12/29/2012 6:00   -13.8             -15.3         88                4
# 8719   12/29/2012 7:00   -14.8             -16.4         88                7
# 8722  12/29/2012 10:00   -12.0             -13.3         90                7
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
Group['Wind Speed_km/h'].max()
# Out:
# Weather
# Clear                                      33
# Cloudy                                     54
# Drizzle                                    30
# Drizzle,Fog                                28
# Drizzle,Ice Pellets,Fog                    20
# Drizzle,Snow                               19
# Drizzle,Snow,Fog                           32
# Fog                                        22
# Freezing Drizzle                           26
# Freezing Drizzle,Fog                       33
# Freezing Drizzle,Haze                      11
# Freezing Drizzle,Snow                      24
# Freezing Fog                                9
# Freezing Rain                              28
# Freezing Rain,Fog                          26
# Freezing Rain,Haze                          9
# Freezing Rain,Ice Pellets,Fog              28
# Freezing Rain,Snow Grains                  32
# Haze                                       17
# Mainly Clear                               63
# ...

# %%
# Details about group:
Group.groups
# Out:
# {'Clear': [67, 114, 115, 116, 117, 241, 242, 243, 244, 344, 351, 352, 353, 354, 355, 356, 357, 358, 359, 360, 361, 362, 363, 364, 365, 366, 425, 426, 427, 428, 429, 430, 431, 432, 433, 434, 435, 436, 437, 438, 439, 440, 441, 465, 467, 468, 469, 494, 495, 496, 497, 498, 499, 500, 501, 502, 504, 505, 506, 525, 601, 602, 603, 604, 605, 606, 608, 695, 696, 698, 699, 700, 701, 702, 703, 704, 710, 822, 823, 824, 825, 827, 832, 833, 834, 835, 836, 837, 838, 839, 840, 841, 842, 843, 844, 845, 846, 847, 848, 849, ...], 'Cloudy': [17, 20, 21, 23, 25, 46, 49, 52, 58, 78, 79, 85, 118, 119, 120, 121, 122, 138, 139, 140, 141, 142, 143, 144, 145, 146, 147, 148, 149, 150, 151, 168, 174, 175, 181, 195, 196, 197, 198, 204, 205, 206, 215, 216, 220, 224, 225, 250, 252, 260, 261, 262, 266, 267, 268, 269, 270, 292, 293, 294, 295, 317, 318, 321, 336, 337, 338, 339, 340, 369, 373, 375, 376, 380, 381, 382, 383, 384, 385, 386, 387, 447, 448, 449, 450, 462, 480, 481, 482, 483, 484, 485, 486, 487, 488, 507, 518
# ...

# %%
for x in Group:
  print(x)
# Out:
# ('Clear',              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
# ...

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
file.groupby('Weather',sort = False).sum()
# Out:
#                                                                                  Date/Time  \
# Weather
# Fog                                      1/1/2012 0:001/1/2012 1:001/1/2012 4:001/1/201...
# Freezing Drizzle,Fog                     1/1/2012 2:001/1/2012 3:001/7/2012 8:001/27/20...
# Mostly Cloudy                            1/1/2012 16:001/2/2012 2:001/2/2012 3:001/2/20...
# Cloudy                                   1/1/2012 17:001/1/2012 20:001/1/2012 21:001/1/...
# Rain                                     1/1/2012 18:001/1/2012 19:001/23/2012 14:001/2...
# Rain Showers                             1/1/2012 22:001/2/2012 0:002/22/2012 15:002/23...
# Mainly Clear                             1/2/2012 12:001/3/2012 12:001/3/2012 13:001/3/...
# Snow Showers                             1/2/2012 17:001/2/2012 20:001/2/2012 21:001/2/...
# Snow                                     1/3/2012 7:001/4/2012 12:001/4/2012 14:001/4/2...
# ...

# %%
# We can find the number of groups in object
len(Group)
# we can find the len of each group
len(Group.get_group('group_name'))

# %%
# GroupBy multi index
file.groupby(['Weather','Wind Speed_km/h']).sum()

# %%
# Concat

file = pd.concat([file,file])
file = pd.concat([file,file['col_name']],axis = 1)

# %%
# Merge DataSet
# Inner merge
file = pd.merge(file1,file2,on='col_name')
# Left merge
file = pd.merge(file1,file2,on='col_name',how='left')
# Right merge
file = pd.merge(file1,file2,on='col_name',how='right')
# Outer merge
file = pd.merge(file1,file2,on='col_name',how='outer')

# %%
# Pivot is used to reshape a given DataFrame organised by given index/column values

df = pd.read_csv('/content/file (1).csv')
df
df.pivot(index="Date/Time",columns="Weather")
df.pivot(index="Date/Time",columns="Weather",values="Wind Speed_km/h")
# Out:
# Weather         Clear  Cloudy  Drizzle  Drizzle,Fog  Drizzle,Ice Pellets,Fog  \
# Date/Time
# 1/1/2012 0:00     NaN     NaN      NaN          NaN                      NaN
# 1/1/2012 10:00    NaN     NaN      NaN          NaN                      NaN
# 1/1/2012 11:00    NaN     NaN      NaN          NaN                      NaN
# 1/1/2012 12:00    NaN     NaN      NaN          NaN                      NaN
# 1/1/2012 13:00    NaN     NaN      NaN          NaN                      NaN
# ...               ...     ...      ...          ...                      ...
# 9/9/2012 5:00    11.0     NaN      NaN          NaN                      NaN
# 9/9/2012 6:00     NaN     NaN      NaN          NaN                      NaN
# 9/9/2012 7:00     NaN     NaN      NaN          NaN                      NaN
# 9/9/2012 8:00     NaN     NaN      NaN          NaN                      NaN
# 9/9/2012 9:00     NaN     NaN      NaN          NaN                      NaN
#
# ...

# %%
# Pivot table
df.pivot_table(index="Date/Time",columns="Weather",values="Wind Speed_km/h")
df.pivot_table(index="Date/Time",columns="Weather",values="Wind Speed_km/h",aggfunc='sum')
df.pivot_table(index="Date/Time",columns="Weather",values="Wind Speed_km/h",aggfunc=['mean','max','sum'])

# %%
# Handel Duplicate value
file.drop_duplicates()
file.drop_duplicates(keep='last')
file.drop_duplicates(keep='first')
file.drop_duplicates(keep='first',ignore_index=True)

# %%
# Working with database

# Read from database
import pandas as pd
import sqlalchemy
engine = sqlalchemy.create_engine('mysql+pymysql://root:@localhost:3306/Database_name')
df_students = pd.read_sql_table("table_name", engine)
df_students

# write to database
df.to_sql(name='table_name',con=engine,index=False,if_exists='append')


# Execute a query
query='''
select student_name, age from students where student_name='arun'
'''
df_query = pd.read_sql_query(query, engine)
df_query

# %%
name = ['Toyota','Honda','BMW','TVS']
price = [23000,24000,25000,26000]
df = pd.DataFrame(list(zip(name,price)),columns=['name','price'])
df
# Out:
#      name  price
# 0  Toyota  23000
# 1   Honda  24000
# 2     BMW  25000
# 3     TVS  26000

# %%
# !pip3 install PyMySQL
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 1.7 MB/s eta 0:00:00
# ...

# %%
# import sqlalchemy
# engine = sqlalchemy.create_engine('mysql+pymysql://root:@127.0.0.1:3306/library')


# try:
#     with engine.connect() as connection:
#         result = connection.execute("SELECT 1")
#         print("Connection successful:", result.fetchone())
# except Exception as e:
#     print("Connection failed:", e)


# df_students = pd.read_sql_table("books", engine)
# df_students
# df.to_sql(name='Motor_Cycle',con=engine,index=False,if_exists='append')
# Out:
# Connection failed: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '127.0.0.1' ([Errno 111] Connection refused)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# !pip install mysql-connector-python
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 34.4 MB/s eta 0:00:00
# ...

# %%
import mysql.connector
connection = mysql.connector.connect(host='localhost',user='root',password='',database='library')

if connection.is_connected():
  print('Connected to MySQL database')
else:
  print('Fail to connect')
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/mysql/connector/connection_cext.py in _open_connection(self)
#     326         try:
# --> 327             self._cmysql.connect(**cnx_kwargs)
#     328             self._cmysql.converter_str_fallback = self._converter_str_fallback
#
# MySQLInterfaceError: Can't connect to MySQL server on 'localhost:3306' (99)
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-36-25d28b1680ff> in <cell line: 2>()
#       1 import mysql.connector
# ----> 2 connection = mysql.connector.connect(host='localhost',user='root',password='',database='library')
#       3
#       4 if connection.is_connected():
#       5   print('Connected to MySQL database')
#
# ...
